# %%
from state_single_tax import *

# %%
# Load the data
csv_path = "state_income_tax_2025.csv"
df = load_tax_data(csv_path)

# Preview
df.head()
# Out:
#   Unnamed: 0 Single Filer Unnamed: 2 Unnamed: 3 Married Filing Jointly  \
# 0      State        Rates        NaN   Brackets                  Rates
# 1       Ala.         0.02          >          0                   0.02
# 2  (a, b, c)         0.04          >        500                   0.04
# 3        NaN         0.05          >       3000                   0.05
# 4        NaN          NaN        NaN        NaN                    NaN
#
#   Unnamed: 5 Unnamed: 6 Standard Deduction Unnamed: 8 Personal Exemption  \
# 0        NaN   Brackets             Single     Couple             Single
# 1          >          0               3000       8500               1500
# 2          >       1000                NaN        NaN                NaN
# 3          >       6000                NaN        NaN                NaN
# 4        NaN        NaN                NaN        NaN                NaN
#
#   Unnamed: 10 Unnamed: 11  state
# 0      Couple   Dependent  State
# ...

# %%
# List all available states
list_all_states()
# Out:
# ['Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming',
#  'District of Columbia']

# %%
# Get tax info for a specific state
state_df = get_state_tax_info(df, "California")
state_df
# Out:
#   Unnamed: 0 Single Filer Unnamed: 2 Unnamed: 3 Married Filing Jointly  \
# 0     Calif.         0.01          >          0                   0.01
#
#   Unnamed: 5 Unnamed: 6 Standard Deduction Unnamed: 8 Personal Exemption  \
# 0          >          0               5540      11080        $149 credit
#
#    Unnamed: 10  Unnamed: 11   state
# 0  $298 credit  $461 credit  Calif.
